# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
base_url = "https://api.covid19api.com/dayone/country/"
end_url = "/status/confirmed"

countries_list = ["Japan"]

for country in countries_list:
    response = requests.get(base_url+country+end_url).json()

# %%
# Out:
#     Country CountryCode Province City CityCode   Lat     Lon  Cases  \
# 0     Japan          JP                         36.2  138.25      2
# 1     Japan          JP                         36.2  138.25      2
# 2     Japan          JP                         36.2  138.25      2
# 3     Japan          JP                         36.2  138.25      2
# 4     Japan          JP                         36.2  138.25      4
# ..      ...         ...      ...  ...      ...   ...     ...    ...
# 171   Japan          JP                         36.2  138.25  21430
# 172   Japan          JP                         36.2  138.25  21841
# 173   Japan          JP                         36.2  138.25  22125
# 174   Japan          JP                         36.2  138.25  22437
# 175   Japan          JP                         36.2  138.25  23172
#
#         Status                  Date
# 0    confirmed  2020-01-22T00:00:00Z
# 1    confirmed  2020-01-23T00:00:00Z
# ...

# %%
Japan_df[["Country", "Cases", "Date"]]
Japan_grouped = Japan_df.groupby("Date")
Japan_data = Japan_grouped.sum()
Japan_data
# Out:
#                       Cases
# Date
# 2020-01-22T00:00:00Z      2
# 2020-01-23T00:00:00Z      2
# 2020-01-24T00:00:00Z      2
# 2020-01-25T00:00:00Z      2
# 2020-01-26T00:00:00Z      4
# ...                     ...
# 2020-07-11T00:00:00Z  21430
# 2020-07-12T00:00:00Z  21841
# 2020-07-13T00:00:00Z  22125
# 2020-07-14T00:00:00Z  22437
# 2020-07-15T00:00:00Z  23172
#
# [176 rows x 1 columns]

# %%
plt.plot(Japan_data)

plt.show()

# %%
aq_path = "Resources/aq2020.csv"

aq_raw = pd.read_csv(aq_path)

aq_raw

# Combine the data into a single dataset.  
#school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
#school_data_complete.head(20)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-67342c6ce063> in <module>
#       1 aq_path = "Resources/aq2020.csv"
#       2
# ----> 3 aq_raw = pd.read_csv(aq_path)
#       4
#       5 aq_raw
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
covid_raw.rename(columns={"date": "Date", "county": "county Name", "state": 'State Name'}, inplace=True)
covid_reduced = covid_raw[["Date", "county Name", "cases", "State Name"]]
covid_reduced

# %%
# Combine the data into a single dataset.  
merge_raw = pd.merge(aq_reduced, covid_reduced, how="inner", on=['State Name',"Date", "county Name"])
merge_raw
#merge_raw.to_csv("Resources/merge.csv")

# %%
westchester = merge_raw.loc[(merge_raw["county Name"]=="Westchester") & (merge_raw["State Name"]=="New York")]
westchester

# %%
#plt.plot(westchester["Date"],westchester["cases"], marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
#plt.plot(westchester["Date"],westchester["AQI"], marker='', color='olive', linewidth=2)
#plt.show()

fig, ax1 = plt.subplots()
