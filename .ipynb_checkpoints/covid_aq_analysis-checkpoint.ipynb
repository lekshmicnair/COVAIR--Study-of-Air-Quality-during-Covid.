# %%
#Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from scipy.stats import linregress

# %%
#Air quality data
aq2020_df = pd.read_csv("Resources/aq2020.csv")
aq2019Q1_df = pd.read_csv("Resources/aq2019Q1.csv")
aq2019Q2_df = pd.read_csv("Resources/aq2019Q2.csv")
aq2019Q3_df = pd.read_csv("Resources/aq2019Q3.csv")

#Format dataframe dates
date_format = [aq2020_df,aq2019Q1_df,aq2019Q2_df,aq2019Q3_df]
for df in date_format:
    df['Date'] = pd.to_datetime(df['Date'])

# %%
#Covid API URL
base_url = "https://api.covid19api.com/dayone/country/"
end_url = "/status/confirmed"

#Enter country
country = "Japan"

response = requests.get(base_url+country+end_url).json()

#On responses, run following code:
variable = pd.DataFrame.from_dict(response, orient='columns')

#Format covid dataframe dates (now mergable with air quality dataframes)
#variable['Date'] = variable['Date'].str.strip('T00:00:00Z')
#variable['Date'] = pd.to_datetime(variable['Date'])
variable
# Out:
#     Country CountryCode Province City CityCode   Lat     Lon  Cases  \
# 0     Japan          JP                         36.2  138.25      2
# 1     Japan          JP                         36.2  138.25      2
# 2     Japan          JP                         36.2  138.25      2
# 3     Japan          JP                         36.2  138.25      2
# 4     Japan          JP                         36.2  138.25      4
# ..      ...         ...      ...  ...      ...   ...     ...    ...
# 173   Japan          JP                         36.2  138.25  22125
# 174   Japan          JP                         36.2  138.25  22437
# 175   Japan          JP                         36.2  138.25  23172
# 176   Japan          JP                         36.2  138.25  23510
# 177   Japan          JP                         36.2  138.25  24104
#
#         Status                  Date
# 0    confirmed  2020-01-22T00:00:00Z
# 1    confirmed  2020-01-23T00:00:00Z
# 2    confirmed  2020-01-24T00:00:00Z
# 3    confirmed  2020-01-25T00:00:00Z
# 4    confirmed  2020-01-26T00:00:00Z
# ..         ...                   ...
# 173  confirmed  2020-07-13T00:00:00Z
# 174  confirmed  2020-07-14T00:00:00Z
# 175  confirmed  2020-07-15T00:00:00Z
# 176  confirmed  2020-07-16T00:00:00Z
# 177  confirmed  2020-07-17T00:00:00Z
#
# [178 rows x 10 columns]

# %%
aq_Japan = aq2020_df.loc[aq2020_df['Country']=="JP"]
aq_Japan['Specie'].unique()
# Out:
# array(['pm25', 'no2', 'dew', 'co', 'o3', 'wind speed', 'wind-gust', 'so2',
#        'pressure', 'wind-speed', 'precipitation', 'pm10', 'temperature',
#        'humidity', 'wind gust'], dtype=object)

# %%
# Out:
#               Date Country     City Specie  count   min   max  median  \
# 0       2020-04-08      PT   Lisbon    no2   85.0   1.8  21.2     6.9
# 1       2020-04-21      PT   Lisbon    no2   94.0   1.1  11.2     3.3
# 2       2020-06-30      PT   Lisbon    no2   59.0   1.1  14.3     5.3
# 3       2020-07-11      PT   Lisbon    no2   74.0   1.4  26.9     7.1
# 4       2020-01-05      PT   Lisbon    no2   72.0   2.7  46.7     8.1
# ...            ...     ...      ...    ...    ...   ...   ...     ...
# 1048570 2020-01-23      CA  Halifax   pm25   46.0  10.0  44.0    20.0
# 1048571        NaT     NaN      NaN    NaN    NaN   NaN   NaN     NaN
# 1048572        NaT     NaN      NaN    NaN    NaN   NaN   NaN     NaN
# 1048573        NaT     NaN      NaN    NaN    NaN   NaN   NaN     NaN
# 1048574        NaT     NaN      NaN    NaN    NaN   NaN   NaN     NaN
#
#          variance
# 0          167.69
# 1           46.31
# 2           96.35
# 3          228.29
# 4         1683.13
# ...           ...
# 1048570    647.44
# 1048571       NaN
# 1048572       NaN
# 1048573       NaN
# 1048574       NaN
#
# [1048575 rows x 9 columns]
